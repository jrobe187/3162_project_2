# %%
import pandas as pd
import numpy as np

# %%
from sklearn.preprocessing import StandardScaler
def standardize(df):
    df = df.dropna()
    scaler = StandardScaler()
    standardized_data = scaler.fit_transform(df)
    df = pd.DataFrame(standardized_data, columns=df.columns)
    return df


    
def drop_variance(df):
    columns = df.columns
    

def fill_with_mean(df):
    pass

# %%
#####1st step in preprocessing, convert string column "Country" to int by giving each country a unique ID
df = pd.read_csv("life expectancy data.csv")
columns = df.columns
countries = df["Country"].unique()
country_ids = {}
status_ids = {"Developing": 0, "Developed": 1}

for idx, string in enumerate(countries):
    country_ids[string] = idx

df['Status'] = df['Status'].replace(status_ids)
df
# Out:
#       Country  Year  Status  Life expectancy   Adult Mortality  infant deaths  \
# 0           0  2015       0              65.0            263.0             62
# 1           0  2014       0              59.9            271.0             64
# 2           0  2013       0              59.9            268.0             66
# 3           0  2012       0              59.5            272.0             69
# 4           0  2011       0              59.2            275.0             71
# ...       ...   ...     ...               ...              ...            ...
# 2933      192  2004       0              44.3            723.0             27
# 2934      192  2003       0              44.5            715.0             26
# 2935      192  2002       0              44.8             73.0             25
# 2936      192  2001       0              45.3            686.0             25
# 2937      192  2000       0              46.0            665.0             24
#
# ...

# %%
df = df.dropna()

# %%
medium_le = np.mean(df["Life expectancy "])
low_le = np.min(df["Life expectancy "])
high_le = np.max(df["Life expectancy "])
percentiles = np.percentile(df["Life expectancy "],[33,67,100])
percentiles
# Out:
# array([66.8, 73.9, 89. ])

# %%
######2nd step, Standardization
df = standardize(df)
df
# Out:
#        Country      Year    Status  Life expectancy   Adult Mortality  \
# 0    -1.648595  1.751998 -0.414725         -0.489223         0.756629
# 1    -1.648595  1.507289 -0.414725         -1.069152         0.820490
# 2    -1.648595  1.262579 -0.414725         -1.069152         0.796542
# 3    -1.648595  1.017869 -0.414725         -1.114637         0.828472
# 4    -1.648595  0.773159 -0.414725         -1.148751         0.852420
# ...        ...       ...       ...               ...              ...
# 1644  1.789322 -0.939811 -0.414725         -2.843056         4.428626
# 1645  1.789322 -1.184521 -0.414725         -2.820313         4.364766
# 1646  1.789322 -1.429231 -0.414725         -2.786200        -0.760066
# 1647  1.789322 -1.673941 -0.414725         -2.729344         4.133270
# 1648  1.789322 -1.918650 -0.414725         -2.649746         3.965635
#
#       infant deaths   Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

# %%
df['Country'] = encoder.fit_transform(df['Country'])
df['Status'] = encoder.fit_transform(df['Status'])
X = df.drop(('Life expectancy '),axis=1)
y = df["Life expectancy "]

X_train, X_tst, y_train, y_tst = train_test_split(X, y, test_size=.2, random_state=42)


rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)
predictions = rf_classifier.predict(X_test)

accuracy = (predictions == y_test).mean()
print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[129], line 11
#       7 X_train, X_tst, y_train, y_tst = train_test_split(X, y, test_size=.2, random_state=42)
#      10 rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
# ---> 11 rf_classifier.fit(X_train, y_train)
#      12 predictions = rf_classifier.predict(X_test)
#      14 accuracy = (predictions == y_test).mean()
#
# File ~\.pyenv\pyenv-win\versions\3.10.5\lib\site-packages\sklearn\ensemble\_forest.py:385, in BaseForest.fit(self, X, y, sample_weight)
#     378         raise ValueError(
#     379             "Sum of y is not strictly positive which "
#     380             "is necessary for Poisson regression."
#     381         )
#     383 self.n_outputs_ = y.shape[1]
# --> 385 y, expanded_class_weight = self._validate_y_class_weight(y)
# ...

# %%
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')
